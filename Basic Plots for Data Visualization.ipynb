# %% [markdown]
# # Some Basic Plots useful for Data Visualization

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#Simple Bar plot
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.bar(x,y)
plt.xlabel('index')
plt.ylabel('values')
plt.show()

# %%
#Bar Plot
x=[1,2,3,4,5,6,7]
y=[25905,9661,20300,21504,22288,27984,19539]
plt.bar(x,y)
plt.xlabel('Provinces')
plt.ylabel('Area')
plt.title('Area of Provinces of Nepal')
plt.show()

# %%
#Horizontal Bar Plot
x=[1,2,3,4,5,6,7]
y=[25905,9661,20300,21504,22288,27984,19539]
plt.ylabel('Provinces')
plt.xlabel('Area (m2)')
plt.title('Area of Provinces of Nepal')
plt.barh(x,y)
plt.show()

# %%
#Assigning Title, axis labels,changing plot color 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.show()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
#Assigning Title, axis labels,changing plot color ,styles
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('seaborn-paper')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color, styles 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('seaborn')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color , styles
plt.title("Population increase Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('classic')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color ,styles
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('dark_background')
plt.show()

# %%
#Assigning Title, axis labels,changing plot styles 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('fivethirtyeight')
plt.show()

# %%
#Assigning Title, axis labels,changing plot styles 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('bmh')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('grayscale')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('seaborn-paper')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color n styles
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('seaborn-notebook')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('seaborn-deep')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('seaborn-ticks')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('seaborn-whitegrid')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('seaborn-poster')
plt.show()

# %%
#Assigning Title, axis labels,changing plot color 
plt.title("Populationincrease Trend of Nepal")
plt.xlabel('years')
plt.ylabel('Increase in population in thousands')
x=[2011,2012,2013,2014,2015,2016,2017,2018]
y=[120,128,133,139,142,146,151,155]
plt.bar(x,y, color='red')
plt.style.use('seaborn-colorblind')
plt.show()

# %%
#Simple Line Plot
plt.plot([1,2,3,4,10],'green')

# %%
#Simple Scatter plot
plt.plot([1,2,3,4,5], [1,2,3,4,10], 'ro') ## 'go' stands for red dots
plt.show()

# %%
#Scatter plot with two sets of points

plt.figure(figsize=(12,8))
x1=[1,2,3,5,8]
y1=[10,17,19,22,18]
x2=[1,3,4,5,6]
y2=[21,12,16,11,19]
plt.plot(x1,y1,'ro',label='RedDots')
plt.plot(x2,y2,'bo',label='BlueDots')
plt.title('A Simple Scatterplot')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(loc='best')
plt.show()

# %%
#Various types of plots as subplots in a layout
# Setup the subplot2grid Layout
fig = plt.figure(figsize=(10, 5))
ax1 = plt.subplot2grid((2,4), (0,0)) 
ax2 = plt.subplot2grid((2,4), (0,1)) 
ax3 = plt.subplot2grid((2,4), (0,2)) 
ax4 = plt.subplot2grid((2,4), (0,3)) 
ax5 = plt.subplot2grid((2,4), (1,0), colspan=2) 
ax6 = plt.subplot2grid((2,4), (1,2)) 
ax7 = plt.subplot2grid((2,4), (1,3)) 

# Input Arrays
n = np.array([0,1,2,3,4,5])
x = np.linspace(0,5,10)
xx = np.linspace(-0.75, 1., 100)

# Scatterplot
ax1.scatter(xx, xx + np.random.randn(len(xx)))
ax1.set_title("Scatter Plot")

# Step Chart
ax2.step(n, n**2, lw=2)
ax2.set_title("Step Plot")

# Bar Chart
ax3.bar(n, n**2, align="center", width=0.5, alpha=0.5)
ax3.set_title("Bar Chart")

# Fill Between
ax4.fill_between(x, x**2, x**3, color="steelblue", alpha=0.5);
ax4.set_title("Fill Between");

# Time Series
dates = pd.date_range('2018-01-01', periods = len(xx))
ax5.plot(dates, xx + np.random.randn(len(xx)))
ax5.set_xticks(dates[::30])
ax5.set_xticklabels(dates.strftime('%Y-%m-%d')[::30])
ax5.set_title("Time Series")

# Box Plot
ax6.boxplot(np.random.randn(len(xx)))
ax6.set_title("Box Plot")

# Histogram
ax7.hist(xx + np.random.randn(len(xx)))
ax7.set_title("Histogram")

fig.tight_layout()

# %%
#Stack Plot, an area plot
Languages = [1,2,3,4,5]
  
Java =[7,8,6,11,7]
Python = [2,3,4,3,2]
Ruby =[7,8,7,2,2]
Php = [8,5,7,8,13]
  
plt.plot([],[],color='m', label='Java', linewidth=5)
plt.plot([],[],color='c', label='Ruby', linewidth=5)
plt.plot([],[],color='r', label='Python', linewidth=5)
plt.plot([],[],color='k', label='Php', linewidth=5)
  
plt.stackplot(Languages, Java,Python,Ruby,Php, colors=['m','c','r','k'])
  
plt.xlabel('x')
plt.ylabel('y')
plt.title('Stack Plot')
plt.legend()
plt.show()

# %%
#pie chart

# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Pie Chart with different Language Use')
plt.show()

# %%
#populations of different provinces of Nepal
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
provinces = ['Province1', 'Province2', 'Province3', 'Gandaki','Province1','Karnali','SudurPaschim']
population = [4534943, 5404145, 5529452, 2403757, 4499272, 1570418, 2552517 ]
colors = ['gold', 'yellowgreen', 'red','lightcoral', 'lightskyblue','orange','green']

ax.pie(population, labels = provinces,autopct='%1.2f%%',colors=colors)
plt.title('Pie Chart showing population of Provinces')
plt.show()

# %% [markdown]
# Boxplots

# %%
# Fixing random state for reproducibility
np.random.seed(9999)

spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Box Plot')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f4fadc05358>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f4fadc05ac8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f4fad736eb8>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f4fadc05f60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f4fadbef588>],
#  'means': []}

# %%
#Multiple Samples Box Plot
spread = np.random.rand(50) * 100
center = np.ones(25) * 40
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
d2 = np.concatenate((spread, center, flier_high, flier_low))
data.shape = (-1, 1)
d2.shape = (-1, 1)
data = [data, d2, d2[::2,0]]
fig7, ax7 = plt.subplots()
ax7.set_title('Multiple Samples with Different sizes')
ax7.boxplot(data)

plt.show()

# %%
#Generate the random data
sequence1 = np.random.randint(0,100,100)
sequence2 = np.random.randint(25,75,100)
sequence3 = np.random.randint(50,80,100)

 
plt.boxplot((sequence1, sequence2, sequence3))
plt.title("Sample BoxPlot2")
plt.show()

# %% [markdown]
# Histogram

# %%
# Random number generation from 0 to 100
x1      = np.random.randint(0,100,100)

 # Plot frequency distribution using histogram
plt.hist(x1, facecolor="r", edgecolor='b')
plt.title("Frequency distribution Histogram - Values from 0-100")
plt.margins(0)
plt.xticks(range(0,110,10))

# Display the histogram

plt.show()

# %% [markdown]
# Sine Wave

# %%
# Get x values of the sine wave
time        = np.arange(0, 10, 0.1);

# Amplitude of the sine wave is sine of a variable like time
amplitude   = np.sin(time)
 

# Plot a sine wave using time and amplitude obtained for the sine wave
plt.plot(time, amplitude)
 
# Give a title for the sine wave plot
plt.title('Sine wave') 

# Give x axis label for the sine wave plot
plt.xlabel('Time')
 
# Give y axis label for the sine wave plot
plt.ylabel('Amplitude = sin(time)')
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.show()

# Display the sine wave
plt.show()

# %% [markdown]
# Cosine Plot

# %%
# Get x values of the cosine wave
time        = np.arange(0, 20, 0.2);

# Amplitude of the cosine wave is cosine of a variable like time
amplitude   = np.cos(time)

# Plot a cosine wave using time and amplitude obtained for the cosine wave
plt.plot(time, amplitude)

# Give a title for the cosine wave plot
plt.title('Cosine wave') 

# Give x axis label for the cosine wave plot
plt.xlabel('Time')

# Give y axis label for the cosine wave plot
plt.ylabel('Amplitude = cosine(time)')

# Draw the grid for the graph
plt.grid(True, which='both')
plt.axhline(y=0, color='b')

 

# Display the cosine wave plot
plt.show()

# %% [markdown]
# DistPlot/ distribution plot

# %%
sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = np.random.randn(100)
ax = sns.distplot(x)
plt.show()

# %%
#From Standard titanic dataset
titanic=sns.load_dataset('titanic')    
age1=titanic['age'].dropna()
sns.distplot(age1)         
plt.show()

# %% [markdown]
# Pair Plots-----visualizing multidimensional relationships

# %%
#from standard iris dataset
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', height=2.5);
